# %% [markdown]
# Текстовый файл text1.txt содержит строку из символов английского алфавита. Найдите символ, который находится на позиции с индексом 1000. Нумерация позиций начинается с нуля. Например, позиция с индексом 2 – третья по счёту позиция.

# %%
f = open("text1.txt")
a = f.readline().split()
f.close()
print(a)
# Out:
# ['123']

# %%
b = "asdfasdf"
print(b)
# Out:
# asdfasdf
